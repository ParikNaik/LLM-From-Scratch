# %%
# %pip install tiktoken
# Out:
# Requirement already satisfied: tiktoken in C:\Users\mckin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.13.0)
# Requirement already satisfied: regex in C:\Users\mckin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from tiktoken) (2026.7.19)
# Requirement already satisfied: requests in C:\Users\mckin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from tiktoken) (2.34.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\mckin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->tiktoken) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\mckin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->tiktoken) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\mckin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->tiktoken) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\mckin\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->tiktoken) (2026.7.22)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.2 -> 26.2
# [notice] To update, run: C:\Users\mckin\AppData\Local\Python\pythoncore-3.14-64\python.exe -m pip install --upgrade pip

# %%
import importlib
import tiktoken

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
text = ("Hello do you like tea? <|endoftext|>In the sunlit terraces of someunknownPlace.")

integers = tokenizer.encode(text, allowed_special={"<|endoftext|>"})

print(integers)
# Out:
# [15496, 466, 345, 588, 8887, 30, 220, 50256, 818, 262, 4252, 18250, 8812, 2114, 286, 617, 34680, 27271, 13]

# %%
strings = tokenizer.decode(integers)

print(strings)
# Out:
# Hello do you like tea? <|endoftext|>In the sunlit terraces of someunknownPlace.

# %%
with open ("the-verdict.txt", "r", encoding = "utf-8") as f:
    raw_text = f.read()

enc_text = tokenizer.encode(raw_text)
